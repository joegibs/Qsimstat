# %%
import sys
sys.path.append("../")

# %%
pip install -r ../requirements.txt
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 934.6 kB/s  0:00:02 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 2.3 MB/s  0:00:04m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 935.6/935.6 kB 2.3 MB/s  0:00:0036m-:--:--
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 986.6/986.6 kB 2.3 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 2.1 MB/s  0:00:01m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 2.3 MB/s  0:00:16m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 2.2 MB/s  0:00:02m0:00:0100:01
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 2.1 MB/s  0:00:09m0:00:0100:01
# ...
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...

# %%
from Experiments import clifford_after_matchgate

# %% [markdown]
# # Might be usefull to create example notebooks as there are a bit easier to manage package requirements and show example scripts and notes

# %%
clifford_after_matchgate.main()
# Out:
# ...
# EXPERIMENT: Clifford After Matchgate on Random MPS
# ...
#
# Parameters:
#   System size (N): 10 qubits
#   Matchgate depth: 50 layers
#   Clifford depth: 50 layers
#   Total depth: 100 layers
#   Data interval: every 10 layers
#   Iterations: 10
#   Results directory: results/clifford_after_matchgate
#
# All statistics enabled:
#   ✓ renyi10
#   ✓ faf
#   ✓ ipr
#   ✓ ess
#   ✓ bonddim
#   ✓ flatness
#   ✓ repulsion
#   ✓ sff
#   ✓ porter_thomas
#   ✓ sre
#
# Running experiment...
#
# Iteration 1/10
# /Users/joeg/Documents/GitHub/qsimproj/Qsimstat/.conda/lib/python3.11/site-packages/cotengra/hyperoptimizers/hyper.py:55: UserWarning: Couldn't find `optuna`, `cmaes`, or `nevergrad` so will use completely random sampling in place of hyper-optimization. It is recommended to install one of these libraries for higher quality contraction paths.
#   warnings.warn(
#   Iteration time: 23.43s
#     Initialization: 1.275s
#     Gate evolution: 1.192s
#     Data collection: 20.963s
#
# Iteration 2/10
# ...
