# %%
import sys
sys.path.append("../")
from Experiments import clifford_after_matchgate

# %% [markdown]
# # Might be usefull to create example notebooks as there are a bit easier to manage package requirements and show example scripts and notes

# %%
clifford_after_matchgate.main()
# Out:
# ======================================================================
# EXPERIMENT: Clifford After Matchgate on Random MPS
# ======================================================================
#
# Parameters:
#   System size (N): 10 qubits
#   Matchgate depth: 50 layers
#   Clifford depth: 50 layers
#   Total depth: 100 layers
#   Data interval: every 10 layers
#   Iterations: 10
#   Results directory: results/clifford_after_matchgate
#
# All statistics enabled:
#   ✓ renyi10
#   ✓ faf
#   ✓ ipr
#   ✓ ess
#   ✓ bonddim
#   ✓ flatness
#   ✓ repulsion
#   ✓ sff
#   ✓ porter_thomas
#   ✓ sre
#
# Running experiment...
#
# Iteration 1/10
# /Users/joeg/anaconda3/envs/quantum/lib/python3.11/site-packages/cotengra/hyperoptimizers/hyper.py:55: UserWarning: Couldn't find `optuna`, `cmaes`, or `nevergrad` so will use completely random sampling in place of hyper-optimization. It is recommended to install one of these libraries for higher quality contraction paths.
#   warnings.warn(
#   Iteration time: 18.73s
#     Initialization: 0.033s
#     Gate evolution: 0.097s
#     Data collection: 18.599s
#
# Iteration 2/10
#   Iteration time: 18.29s
#     Initialization: 0.001s
#     Gate evolution: 0.082s
#     Data collection: 18.207s
#
# Iteration 3/10
#   Iteration time: 18.03s
#     Initialization: 0.001s
#     Gate evolution: 0.083s
#     Data collection: 17.945s
#
# Iteration 4/10
#   Iteration time: 18.00s
#     Initialization: 0.001s
#     Gate evolution: 0.082s
#     Data collection: 17.912s
#
# Iteration 5/10
#   Iteration time: 17.82s
#     Initialization: 0.001s
#     Gate evolution: 0.084s
#     Data collection: 17.740s
#
# Iteration 6/10
#   Iteration time: 18.16s
#     Initialization: 0.002s
#     Gate evolution: 0.089s
#     Data collection: 18.065s
#
# Iteration 7/10
#   Iteration time: 17.92s
#     Initialization: 0.001s
#     Gate evolution: 0.082s
#     Data collection: 17.836s
#
# Iteration 8/10
#   Iteration time: 17.39s
#     Initialization: 0.001s
#     Gate evolution: 0.081s
#     Data collection: 17.309s
#
# Iteration 9/10
#   Iteration time: 17.50s
#     Initialization: 0.001s
#     Gate evolution: 0.080s
#     Data collection: 17.419s
#
# Iteration 10/10
#   Iteration time: 17.59s
#     Initialization: 0.009s
#     Gate evolution: 0.083s
#     Data collection: 17.494s
#
# ======================================================================
# TIMING SUMMARY
# ======================================================================
#
# Per iteration averages (10 iterations):
#   Gate evolution:   0.084s ± 0.005s
#   Data collection:  17.853s ± 0.369s
#   Total per iter:   17.937s
#
# Data collection breakdown (average per iteration):
#   faf            : 10.905s ± 0.139s
#   sre            : 6.867s ± 0.252s
#   renyi10        : 0.022s ± 0.004s
#   ess            : 0.015s ± 0.002s
#   repulsion      : 0.015s ± 0.000s
#   flatness       : 0.012s ± 0.001s
#   sff            : 0.011s ± 0.000s
#   porter_thomas  : 0.003s ± 0.000s
#   ipr            : 0.002s ± 0.000s
#
# Total experiment time: 179.37s
#   Gate evolution:   0.84s (0.5%)
#   Data collection:  178.53s (99.5%)
#
# ======================================================================
# SAVING DATA
# ======================================================================
#   Saved renyi10: results/clifford_after_matchgate/renyi10/10qubits_10iter_10interval_20251120_110742.npy
#   Saved faf: results/clifford_after_matchgate/faf/10qubits_10iter_10interval_20251120_110742.npy
#   Saved ipr: results/clifford_after_matchgate/ipr/10qubits_10iter_10interval_20251120_110742.npy
#   Saved ess: results/clifford_after_matchgate/ess/10qubits_10iter_10interval_20251120_110742.npy
#   Saved bonddim: results/clifford_after_matchgate/bonddim/10qubits_10iter_10interval_20251120_110742.npy
#   Saved flatness: results/clifford_after_matchgate/flatness/10qubits_10iter_10interval_20251120_110742.npy
#   Saved repulsion: results/clifford_after_matchgate/repulsion/10qubits_10iter_10interval_20251120_110742.npy
#   Saved sff: results/clifford_after_matchgate/sff/10qubits_10iter_10interval_20251120_110742.npy
#   Saved porter_thomas: results/clifford_after_matchgate/porter_thomas/10qubits_10iter_10interval_20251120_110742.npy
#   Saved sre: results/clifford_after_matchgate/sre/10qubits_10iter_10interval_20251120_110742.npy
#
# All data saved to results/clifford_after_matchgate/
#
# ======================================================================
# EXPERIMENT COMPLETE!
# ======================================================================
#
# Results saved to: results/clifford_after_matchgate/
