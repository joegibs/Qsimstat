# %%
import sys
sys.path.append("../")
from Experiments import clifford_after_matchgate

# %% [markdown]
# # Might be usefull to create example notebooks as there are a bit easier to manage package requirements and show example scripts and notes

# %%
clifford_after_matchgate.main()
# Out:
# ======================================================================
# EXPERIMENT: Clifford After Matchgate on Random MPS
# ======================================================================
#
# Parameters:
#   System size (N): 10 qubits
#   Matchgate depth: 50 layers
#   Clifford depth: 50 layers
#   Total depth: 100 layers
#   Data interval: every 10 layers
#   Iterations: 10
#   Results directory: results/clifford_after_matchgate
#
# All statistics enabled:
#   ✓ renyi10
#   ✓ faf
#   ✓ ipr
#   ✓ ess
#   ✓ bonddim
#   ✓ flatness
#   ✓ repulsion
#   ✓ sff
#   ✓ porter_thomas
#   ✓ sre
#
# Running experiment...
#
# Iteration 1/10
# /Users/joeg/anaconda3/envs/quantum/lib/python3.11/site-packages/cotengra/hyperoptimizers/hyper.py:55: UserWarning: Couldn't find `optuna`, `cmaes`, or `nevergrad` so will use completely random sampling in place of hyper-optimization. It is recommended to install one of these libraries for higher quality contraction paths.
#   warnings.warn(
#   Iteration time: 18.73s
#     Initialization: 0.033s
#     Gate evolution: 0.097s
#     Data collection: 18.599s
#
# Iteration 2/10
